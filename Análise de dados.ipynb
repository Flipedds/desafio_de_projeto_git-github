# %%
import pandas  as  pd
#abrir arquivo excel
tabela = pd.read_excel( "/content/drive/MyDrive/Análise de dados_1.xlsx") 
print ( tabela )
# Out:
#       vendas  paletós  gravatas  sapatos
# 0    janeiro    550.0      25.0     30.0
# 1  fevereiro    220.0      30.0     20.0
# 2      marco    300.0      80.0     55.0
# 3      abril    400.0      15.0     10.0

# %%
#renomear colunas
tabela.rename(columns={"vendas":"venda"})

# %%
#tabela formatada
tabela.head()
# Out:
#       vendas  paletós  gravatas  sapatos
# 0    janeiro    550.0      25.0     30.0
# 1  fevereiro    220.0      30.0     20.0
# 2      marco    300.0      80.0     55.0
# 3      abril    400.0      15.0     10.0

# %%
#total de linhas e colunas
tabela.shape
# Out:
# (4, 4)

# %%
#colunas da tabela
tabela.columns
# Out:
# Index(['vendas', 'paletós', 'gravatas', 'sapatos'], dtype='object')

# %%
#tipos dos dados
tabela.dtypes
# Out:
# vendas       object
# paletós     float64
# gravatas    float64
# sapatos     float64
# dtype: object

# %%
#escolher quantas mostrar
tabela.tail(2)
# Out:
#   vendas  paletós  gravatas  sapatos
# 2  marco    300.0      80.0     55.0
# 3  abril    400.0      15.0     10.0

# %%
tabela.describe
# Out:
# <bound method NDFrame.describe of       vendas  paletós  gravatas  sapatos
# 0    janeiro    550.0      25.0     30.0
# 1  fevereiro    220.0      30.0     20.0
# 2      marco    300.0      80.0     55.0
# 3      abril    400.0      15.0     10.0>

# %%
#filtro
tabela["paletós"].unique()
# Out:
# array([550., 220., 300., 400.])

# %%
sapatos = tabela.loc[tabela["sapatos"] == "janeiro"]
sapatos.head()
# Out:
# Empty DataFrame
# Columns: [vendas, paletós, gravatas, sapatos]
# Index: []

# %%
#contar igualdade entre duas colunas
tabela.groupby("sapatos")["gravatas"]

# %%
#média
tabela.groupby("gravatas")["sapatos"].mean()
# Out:
# gravatas
# 15.0    10.0
# 25.0    30.0
# 30.0    20.0
# 80.0    55.0
# Name: sapatos, dtype: float64

# %%
#média coluna
tabela["gravatas"].mean()
# Out:
# 37.5

# %%
tabela["gravatas"].sum()
# Out:
# 150.0
